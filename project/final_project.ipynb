# %% [markdown]
# # Social Media Sentiment Analysis and Engagement Prediction

# %% [markdown]
# **Dataset:** Social Media Sentiment Analysis Dataset
#
# **Goals:**
#
# 1. Understand sentiment distribution across platforms.
# 2. Analyze temporal sentiment trends over time.
# 3. Study engagement (likes/retweets) vs sentiment.
# 4. Identify trending hashtags/topics and their sentiment/engagement patterns.
# 5. Examine geographical sentiment differences.
# 6. (Optional) Predict engagement based on sentiment/topic/platform.

# %% [markdown]
# ## 1. Imports & Setup (Code Cell)

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from pathlib import Path
from collections import Counter
import re

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression, Ridge
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestRegressor
from sklearn.multiclass import OneVsRestClassifier
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    accuracy_score,
    f1_score,
    mean_squared_error,
    r2_score,
)
from scipy.stats import chi2_contingency, kruskal

sns.set_theme(style="whitegrid")

# %% [markdown]
# ## 2. Load Dataset
#
# We load the raw dataset, remove duplicate/unused index columns, normalize categorical text fields, and check the basic structure. These cleaning steps are important because the original dataset contains extra whitespace in categories such as `Platform`, `Sentiment`, and `Country`.

# %%
# Robust data loading: works both when the CSV is in the notebook folder
# and when it is stored under a local data/ directory.
possible_paths = [
    Path("sentimentdataset.csv"),
    Path("data/sentimentdataset.csv"),
]

for path in possible_paths:
    if path.exists():
        data_path = path
        break
else:
    raise FileNotFoundError("Could not find sentimentdataset.csv. Place it in the notebook folder or data/ directory.")

raw_df = pd.read_csv(data_path)
print("Loaded from:", data_path)
print("Raw shape:", raw_df.shape)
raw_df.head()
# Out:
# Loaded from: sentimentdataset.csv
# Raw shape: (732, 15)
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#              Timestamp            User     Platform  \
# 0  2023-01-15 12:30:00   User123          Twitter
# 1  2023-01-15 08:45:00   CommuterX        Twitter
# 2  2023-01-15 15:45:00   FitnessFan      Instagram
# 3  2023-01-15 18:20:00   AdventureX       Facebook
# 4  2023-01-15 19:55:00   ChefCook        Instagram
#
# ...

# %%
df = raw_df.copy()

# Standardize column names and remove accidental index columns from CSV exports.
df.columns = df.columns.str.strip()
df = df.loc[:, ~df.columns.str.contains(r"^Unnamed", case=False, regex=True)]

# Normalize text/category fields. This avoids treating values like "Twitter" and " Twitter" as different platforms.
text_cols = ["Text", "Sentiment", "Platform", "Country", "Hashtags"]
for col in text_cols:
    if col in df.columns:
        df[col] = df[col].astype(str).str.strip()

# Convert numeric engagement columns safely.
for col in ["Likes", "Retweets"]:
    df[col] = pd.to_numeric(df[col], errors="coerce")

# Convert timestamps safely.
df["Timestamp"] = pd.to_datetime(df["Timestamp"], errors="coerce")

print("Cleaned shape before dropping missing/duplicates:", df.shape)
df.info()
# Out:
# Cleaned shape before dropping missing/duplicates: (732, 13)
# <class 'pandas.DataFrame'>
# RangeIndex: 732 entries, 0 to 731
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Text       732 non-null    str
#  1   Sentiment  732 non-null    str
#  2   Timestamp  732 non-null    datetime64[us]
#  3   User       732 non-null    str
#  4   Platform   732 non-null    str
#  5   Hashtags   732 non-null    str
#  6   Retweets   732 non-null    float64
#  7   Likes      732 non-null    float64
#  8   Country    732 non-null    str
#  9   Year       732 non-null    int64
#  10  Month      732 non-null    int64
#  11  Day        732 non-null    int64
#  12  Hour       732 non-null    int64
# dtypes: datetime64[us](1), float64(2), int64(4), str(6)
# memory usage: 74.5 KB

# %%
df.describe(include="all")
# Out:
#                                                      Text Sentiment  \
# count                                                 732       732
# unique                                                706       191
# top     A compassionate rain, tears of empathy falling...  Positive
# freq                                                    3        45
# mean                                                  NaN       NaN
# min                                                   NaN       NaN
# 25%                                                   NaN       NaN
# 50%                                                   NaN       NaN
# 75%                                                   NaN       NaN
# max                                                   NaN       NaN
# std                                                   NaN       NaN
#
#                          Timestamp               User   Platform  \
# count                          732                732        732
# ...

# %% [markdown]
# We inspect missing values and duplicates after basic normalization.

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# Text         0
# Sentiment    0
# Timestamp    0
# User         0
# Platform     0
# Hashtags     0
# Retweets     0
# Likes        0
# Country      0
# Year         0
# Month        0
# Day          0
# Hour         0
# dtype: int64

# %%
dup_count = df.duplicated().sum()
dup_count
# Out:
# np.int64(21)

# %%
df = df.drop_duplicates()
df = df.dropna(subset=["Text", "Sentiment", "Platform", "Timestamp", "Likes", "Retweets"])
df = df[(df["Likes"] >= 0) & (df["Retweets"] >= 0)].copy()

print("After dropping duplicates, missing key fields, and invalid engagement values:", df.shape)
# Out:
# After dropping duplicates, missing key fields, and invalid engagement values: (711, 13)

# %% [markdown]
# We validate categorical columns and engagement columns.

# %%
for col in ["Sentiment", "Platform", "Country"]:
    print("\n===", col, "===")
    print("Unique values:", df[col].nunique())
    print(df[col].value_counts().head(10))
# Out:
# === Sentiment ===
# Unique values: 191
# Sentiment
# Positive       45
# Joy            44
# Excitement     37
# Neutral        18
# Contentment    18
# Gratitude      17
# Curiosity      16
# Serenity       15
# Happy          14
# Despair        11
# Name: count, dtype: int64
#
# === Platform ===
# Unique values: 3
# Platform
# Instagram    252
# Twitter      236
# Facebook     223
# Name: count, dtype: int64
#
# === Country ===
# Unique values: 33
# Country
# USA          184
# UK           140
# Canada       132
# Australia     70
# India         68
# Brazil        17
# France        16
# Japan         15
# Germany       14
# Italy         11
# Name: count, dtype: int64

# %%
for col in ["Likes", "Retweets"]:
    print(col, "min/max:", df[col].min(), df[col].max())
# Out:
# Likes min/max: 10.0 80.0
# Retweets min/max: 5.0 40.0

# %%
df["Timestamp"].isna().sum()
# Out:
# np.int64(0)

# %%
print("Final cleaned dataset shape:", df.shape)
# Out:
# Final cleaned dataset shape: (711, 13)

# %% [markdown]
# ## 3. Text Cleaning (Markdown Cell)
#
# We clean raw text but **keep hashtags** for topic analysis.
#
# ---
#
# ##  Define Cleaning Function (Code Cell)

# %%
def clean_text(t):
    t = str(t).lower()
    t = re.sub(r"http\S+", "", t)       # remove URLs
    t = re.sub(r"@\w+", "", t)          # remove @mentions
    t = re.sub(r"\s+", " ", t).strip()  # normalize whitespace
    return t

df["clean_text"] = df["Text"].apply(clean_text)
df[["Text", "clean_text", "Sentiment", "Platform"]].head()
# Out:
#                                           Text  \
# 0        Enjoying a beautiful day at the park!
# 1           Traffic was terrible this morning.
# 2          Just finished an amazing workout! 💪
# 3  Excited about the upcoming weekend getaway!
# 4  Trying out a new recipe for dinner tonight.
#
#                                     clean_text Sentiment   Platform
# 0        enjoying a beautiful day at the park!  Positive    Twitter
# 1           traffic was terrible this morning.  Negative    Twitter
# 2          just finished an amazing workout! 💪  Positive  Instagram
# 3  excited about the upcoming weekend getaway!  Positive   Facebook
# 4  trying out a new recipe for dinner tonight.   Neutral  Instagram

# %%
df = df[df["clean_text"].str.len() > 0].copy()
print("After text cleaning:", df.shape)
# Out:
# After text cleaning: (711, 14)

# %%
output_dir = Path("data")
output_dir.mkdir(exist_ok=True)
df.to_csv(output_dir / "df_clean.csv", index=False)
df.to_csv("df_clean.csv", index=False)
print("Saved cleaned files to data/df_clean.csv and df_clean.csv")
# Out:
# Saved cleaned files to data/df_clean.csv and df_clean.csv

# %% [markdown]
# ## 4. Exploratory Data Analysis (EDA)
#
# We explore:
#
# * overall sentiment distribution
# * platform-specific sentiment
# * sentiment trends over time
# * engagement vs sentiment
# * hashtag/topic trends
# * geographical sentiment
#
# ---

# %%
N = 20
sent_counts = df["Sentiment"].value_counts().head(N).reset_index()
sent_counts.columns = ["Sentiment", "count"]

plt.figure(figsize=(10,6))
sns.barplot(data=sent_counts, x="Sentiment", y="count", hue="Sentiment", legend=False)
plt.title("Top 20 Sentiments")
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# Select top N emotions for clearer visualization.
N = 20
topN = df["Sentiment"].value_counts().head(N).index
df_top = df[df["Sentiment"].isin(topN)].copy()

plt.figure(figsize=(10,6))
sns.countplot(data=df_top, x="Platform", hue="Sentiment")
plt.title("Top 20 Sentiments by Platform")
plt.xticks(rotation=45, ha='right')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
import matplotlib.dates as mdates

# Daily trends are only meaningful where the data is dense, so focus on the year with the most posts.
trend_sentiments = df_top["Sentiment"].value_counts().head(8).index
active_year = df_top["Timestamp"].dt.year.value_counts().idxmax()
df_daily = df_top[
    df_top["Sentiment"].isin(trend_sentiments)
    & (df_top["Timestamp"].dt.year == active_year)
].copy()
df_daily.loc[:, "date"] = df_daily["Timestamp"].dt.floor("D")

daily_counts = (
    df_daily.groupby(["date", "Sentiment"])
    .size()
    .unstack(fill_value=0)
    .asfreq("D", fill_value=0)
    .reindex(columns=trend_sentiments, fill_value=0)
)
daily_rolling = daily_counts.rolling(window=7, min_periods=1).sum()
daily = daily_rolling.reset_index().melt(id_vars="date", var_name="Sentiment", value_name="count")

fig, ax = plt.subplots(figsize=(13, 6))
palette = sns.color_palette("tab10", n_colors=len(daily_rolling.columns))
for sentiment, color in zip(daily_rolling.columns, palette):
    ax.plot(daily_rolling.index, daily_rolling[sentiment], linewidth=2, label=sentiment, color=color)

ax.set_title(f"Daily Sentiment Trends in {active_year} (Top 8, 7-Day Rolling Count)")
ax.set_xlabel("Month")
ax.set_ylabel("Posts in Previous 7 Days")
ax.set_ylim(bottom=0)
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax.xaxis.set_major_formatter(mdates.DateFormatter("%b"))
ax.grid(alpha=0.25)
ax.legend(title="Sentiment", loc="upper left", bbox_to_anchor=(1.02, 1), frameon=False)
plt.tight_layout()
plt.show()

# %%
df["date"] = df["Timestamp"].dt.date
daily = df.groupby(["date", "Sentiment"]).size().reset_index(name="count")
daily.head()
# Out:
#          date    Sentiment  count
# 0  2010-05-15      Elation      1
# 1  2010-08-15  Contentment      1
# 2  2010-11-12  Contentment      1
# 3  2011-06-20  Contentment      1
# 4  2011-07-22     Serenity      1

# %%
import matplotlib.dates as mdates

# Match the daily view: weekly trends are clearer in the densest year than across sparse multi-year data.
trend_sentiments = df_top["Sentiment"].value_counts().head(8).index
active_year = df_top["Timestamp"].dt.year.value_counts().idxmax()
df_weekly = df_top[
    df_top["Sentiment"].isin(trend_sentiments)
    & (df_top["Timestamp"].dt.year == active_year)
].copy()

weekly_counts = (
    df_weekly.groupby([pd.Grouper(key="Timestamp", freq="W"), "Sentiment"])
    .size()
    .unstack(fill_value=0)
    .asfreq("W", fill_value=0)
    .reindex(columns=trend_sentiments, fill_value=0)
)
weekly_rolling = weekly_counts.rolling(window=4, min_periods=1).sum()
weekly = weekly_rolling.reset_index().melt(id_vars="Timestamp", var_name="Sentiment", value_name="count")

fig, ax = plt.subplots(figsize=(13, 6))
palette = sns.color_palette("tab10", n_colors=len(weekly_rolling.columns))
for sentiment, color in zip(weekly_rolling.columns, palette):
    ax.plot(weekly_rolling.index, weekly_rolling[sentiment], linewidth=2, label=sentiment, color=color)

ax.set_title(f"Weekly Sentiment Trends in {active_year} (Top 8, 4-Week Rolling Count)")
ax.set_xlabel("Month")
ax.set_ylabel("Posts in Previous 4 Weeks")
ax.set_ylim(bottom=0)
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax.xaxis.set_major_formatter(mdates.DateFormatter("%b"))
ax.grid(alpha=0.25)
ax.legend(title="Sentiment", loc="upper left", bbox_to_anchor=(1.02, 1), frameon=False)
plt.tight_layout()
plt.show()

# %%
eng = df_top.groupby("Sentiment")[["Likes", "Retweets"]].mean().sort_values("Likes", ascending=False).reset_index()

plt.figure(figsize=(10,6))
sns.barplot(data=eng, x="Sentiment", y="Likes", hue="Sentiment", legend=False)
plt.title("Average Likes by Sentiment (Top 20)")
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data=df_top, x="Sentiment", y="Likes")
plt.title("Likes Distribution by Sentiment (Top 20)")
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
eng = df.groupby("Sentiment")[["Likes","Retweets"]].mean().sort_values("Likes", ascending=False)
eng
# Out:
#                   Likes   Retweets
# Sentiment
# Motivation    80.000000  40.000000
# Mesmerizing   80.000000  40.000000
# Wonder        73.333333  36.666667
# Energy        70.000000  35.000000
# Mindfulness   70.000000  35.000000
# ...                 ...        ...
# Boredom       20.000000  10.000000
# Numbness      18.666667   9.500000
# Jealousy      18.333333   9.333333
# Resentment    18.333333   9.000000
# Helplessness  15.000000   8.000000
#
# [191 rows x 2 columns]

# %% [markdown]
# We identify top hashtags and study their sentiment/engagement.
#
# ---
#
# ###  Parse Hashtags (Code Cell)

# %%
def split_tags(x):
    if pd.isna(x):
        return []
    tags = re.findall(r"#?([A-Za-z0-9_]+)", str(x).lower())
    return [t for t in tags if t]

df["tag_list"] = df["Hashtags"].apply(split_tags)
df[["Hashtags", "tag_list"]].head()
# Out:
#              Hashtags             tag_list
# 0       #Nature #Park       [nature, park]
# 1   #Traffic #Morning   [traffic, morning]
# 2   #Fitness #Workout   [fitness, workout]
# 3  #Travel #Adventure  [travel, adventure]
# 4      #Cooking #Food      [cooking, food]

# %%
all_tags = sum(df["tag_list"].tolist(), [])
tag_counts = Counter(all_tags).most_common(20)
tags_df = pd.DataFrame(tag_counts, columns=["hashtag", "count"])

plt.figure(figsize=(8,8))
sns.barplot(data=tags_df, x="count", y="hashtag", hue="hashtag", legend=False)
plt.title("Top 20 Hashtags")
plt.xlabel("Count")
plt.ylabel("Hashtag")
plt.show()

# %%
country_counts = df_top["Country"].value_counts().head(10).index
df_country_top = df_top[df_top["Country"].isin(country_counts)].copy()

country_sent_counts = df_country_top.groupby(["Country", "Sentiment"]).size().unstack(fill_value=0)
country_sent = country_sent_counts.div(country_sent_counts.sum(axis=1), axis=0)

plt.figure(figsize=(12,8))
sns.heatmap(country_sent, cmap="Blues")
plt.title("Sentiment Share by Country (Top 10 Countries, Top 20 Sentiments)")
plt.xlabel("Sentiment")
plt.ylabel("Country")
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# ## 5. Sentiment Classification Models
#
# We train baseline models:
#
# 1. TF-IDF + Logistic Regression
# 2. TF-IDF + Linear SVM

# %% [markdown]
# ## 5.1 Preparation

# %%
# Filter by top N sentiments to reduce extreme class sparsity for baseline modeling.
N = 20
topN = df["Sentiment"].value_counts().head(N).index
df_model = df[df["Sentiment"].isin(topN)].copy()

X_text = df_model["clean_text"]
y = df_model["Sentiment"]

X_train, X_test, y_train, y_test = train_test_split(
    X_text,
    y,
    test_size=0.2,
    random_state=42,
    stratify=y,
)

print("Train size:", len(X_train))
print("Test size:", len(X_test))
print("Classes:", y.nunique())
# Out:
# Train size: 255
# Test size: 64
# Classes: 20

# %% [markdown]
# ## 5.2 Logistic Regression

# %%
lr_clf = Pipeline([
    ("tfidf", TfidfVectorizer(max_features=5000, ngram_range=(1,2))),
    ("lr", OneVsRestClassifier(LogisticRegression(max_iter=1000, solver="liblinear")))
])

lr_clf.fit(X_train, y_train)
pred_lr = lr_clf.predict(X_test)

print(classification_report(y_test, pred_lr, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#   Acceptance       1.00      1.00      1.00         2
#          Awe       1.00      0.50      0.67         2
#    Confusion       0.00      0.00      0.00         1
#  Contentment       0.00      0.00      0.00         4
#    Curiosity       1.00      0.33      0.50         3
#      Despair       0.00      0.00      0.00         2
#      Elation       0.00      0.00      0.00         1
#  Embarrassed       0.00      0.00      0.00         2
#   Excitement       0.75      0.43      0.55         7
#    Gratitude       1.00      0.33      0.50         3
#        Grief       0.00      0.00      0.00         2
#        Happy       0.00      0.00      0.00         3
#          Joy       0.23      0.78      0.36         9
#   Loneliness       0.00      0.00      0.00         2
#      Neutral       0.00      0.00      0.00         4
#    Nostalgia       1.00      0.50      0.67         2
# ...

# %% [markdown]
# ## 5.3 Linear SVM

# %%
svm_clf = Pipeline([
    ("tfidf", TfidfVectorizer(max_features=5000, ngram_range=(1,2))),
    ("svm", LinearSVC())
])

svm_clf.fit(X_train, y_train)
pred_svm = svm_clf.predict(X_test)

print(classification_report(y_test, pred_svm, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#   Acceptance       1.00      1.00      1.00         2
#          Awe       1.00      0.50      0.67         2
#    Confusion       1.00      1.00      1.00         1
#  Contentment       0.67      0.50      0.57         4
#    Curiosity       1.00      1.00      1.00         3
#      Despair       0.67      1.00      0.80         2
#      Elation       1.00      1.00      1.00         1
#  Embarrassed       1.00      0.50      0.67         2
#   Excitement       1.00      0.57      0.73         7
#    Gratitude       0.75      1.00      0.86         3
#        Grief       1.00      1.00      1.00         2
#        Happy       0.00      0.00      0.00         3
#          Joy       0.38      0.67      0.48         9
#   Loneliness       1.00      1.00      1.00         2
#      Neutral       0.20      0.25      0.22         4
#    Nostalgia       1.00      1.00      1.00         2
# ...

# %%
labels = sorted(df_model["Sentiment"].unique())
cm = confusion_matrix(y_test, pred_svm, labels=labels)

plt.figure(figsize=(12,10))
sns.heatmap(cm, annot=False, cmap="Blues", xticklabels=labels, yticklabels=labels)
plt.title("Confusion Matrix: Linear SVM")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.show()

# %% [markdown]
# # 6. Hypothesis Testing
#
# In this section, we test several exploratory hypotheses derived from EDA. We use the cleaned dataset restricted to the Top 20 most frequent sentiment categories (`df_model`) to reduce class sparsity.
#
# Important note: because this dataset is small and some category combinations still have low counts, the statistical tests should be interpreted as exploratory evidence rather than definitive causal conclusions.

# %% [markdown]
# 6.1. **H1: Sentiment distribution differs across platforms.**
#    → Use Chi-square test of independence.

# %%
# H1: Platform and sentiment association.
contingency = pd.crosstab(df_model["Platform"], df_model["Sentiment"])

chi2, p, dof, expected = chi2_contingency(contingency)
expected = pd.DataFrame(expected, index=contingency.index, columns=contingency.columns)

print("=== Chi-square Test: Platform vs Sentiment ===")
print("chi2:", chi2)
print("p-value:", p)
print("degrees of freedom:", dof)
print("minimum expected count:", expected.min().min())
print("share of expected counts < 5:", (expected < 5).to_numpy().mean())
# Out:
# === Chi-square Test: Platform vs Sentiment ===
# chi2: 16.98990391166422
# p-value: 0.9987111222567786
# degrees of freedom: 38
# minimum expected count: 2.1065830721003134
# share of expected counts < 5: 0.6166666666666667

# %%
plt.figure(figsize=(14,6))
sns.heatmap(contingency, cmap="Blues")
plt.title("Platform × Sentiment Contingency Table (Counts)")
plt.xlabel("Sentiment")
plt.ylabel("Platform")
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# If p < 0.05, we reject H₀ and conclude that sentiment distribution is associated with platform in this sample.
# If p >= 0.05, we fail to reject H₀ and conclude there is no evidence of a statistically significant association in this sample.
#
# Because some expected counts may be small, this result should be interpreted cautiously.

# %% [markdown]
# 6.2. **H2: Engagement (likes) differs significantly by sentiment category.**
#    → Use Kruskal–Wallis H-test (non-parametric).

# %%
groups = [
    df_model.loc[df_model["Sentiment"] == s, "Likes"]
    for s in df_model["Sentiment"].unique()
]

stat, p = kruskal(*groups)

print("=== Kruskal-Wallis Test: Sentiment vs Likes ===")
print("statistic:", stat)
print("p-value:", p)
# Out:
# === Kruskal-Wallis Test: Sentiment vs Likes ===
# statistic: 69.49955908527846
# p-value: 1.1137863112459559e-07

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data=df_model, x="Sentiment", y="Likes")
plt.title("Likes Distribution across Sentiments")
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# If p < 0.05, we reject H₀ and conclude that at least one sentiment category has a different likes distribution in this sample.
#
# If p >= 0.05, we do not have evidence that likes differ across sentiment categories in this sample.
#
# This test shows association, not causation; engagement can be affected by many missing factors such as follower count, posting time, and current events.

# %% [markdown]
# 6.3. **H3: Sentiment distribution differs across countries.**
#    → Use Chi-square test again (categorical × categorical).

# %%
# Restrict to top countries to reduce sparse matrix issues.
top_countries = df_model["Country"].value_counts().head(10).index
df_country = df_model[df_model["Country"].isin(top_countries)].copy()

cont_country = pd.crosstab(df_country["Country"], df_country["Sentiment"])

chi2_c, p_c, dof_c, expected_c = chi2_contingency(cont_country)
expected_c = pd.DataFrame(expected_c, index=cont_country.index, columns=cont_country.columns)

print("=== Chi-square Test: Country vs Sentiment ===")
print("chi2:", chi2_c)
print("p-value:", p_c)
print("degrees of freedom:", dof_c)
print("minimum expected count:", expected_c.min().min())
print("share of expected counts < 5:", (expected_c < 5).to_numpy().mean())
# Out:
# === Chi-square Test: Country vs Sentiment ===
# chi2: 192.4253990058338
# p-value: 0.12525358385513638
# degrees of freedom: 171
# minimum expected count: 0.026058631921824105
# share of expected counts < 5: 0.945

# %%
plt.figure(figsize=(14,10))
sns.heatmap(cont_country, cmap="Reds")
plt.title("Country × Sentiment Contingency Table (Top 10 Countries)")
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# A significant p-value (p < 0.05) suggests that sentiment distribution is associated with country in this sample. However, because country-sentiment combinations can be sparse, this result should be treated as exploratory rather than conclusive.

# %% [markdown]
# # 7. Engagement Prediction (Likes / Retweets)
#
# In this section, we attempt to predict engagement metrics — specifically **likes** — based on
# post-level features such as sentiment, platform, and hashtags. This can help identify which types
# of content tend to receive higher engagement, enabling applications in marketing, recommendation,
# and social media strategy.
#
# We use the cleaned dataset restricted to the Top 20 most frequent sentiments (`df_model`).
#
# We follow these steps:
#
# 1. Feature Engineering
# 2. Preparing Train/Test Split
# 3. Baseline Models
# 4. Feature Importance
# 5. (Optional) Extending to text-based models (TF-IDF + Regression)

# %%
df_model = df_model.copy()
df_model["tag_list"] = df_model["Hashtags"].apply(split_tags)
df_model["hashtag_count"] = df_model["tag_list"].apply(len)

# Log transform engagement metrics to reduce the effect of extreme values.
df_model["log_likes"] = np.log1p(df_model["Likes"])
df_model["log_retweets"] = np.log1p(df_model["Retweets"])

df_model[["Likes", "Retweets", "log_likes", "log_retweets", "hashtag_count"]].head()
# Out:
#    Likes  Retweets  log_likes  log_retweets  hashtag_count
# 0   30.0      15.0   3.433987      2.772589              2
# 2   40.0      20.0   3.713572      3.044522              2
# 3   15.0       8.0   2.772589      2.197225              2
# 4   25.0      12.0   3.258097      2.564949              2
# 5   50.0      25.0   3.931826      3.258097              2

# %%
X = pd.get_dummies(
    df_model[["Sentiment", "Platform", "hashtag_count"]],
    drop_first=True
)

y_likes = df_model["log_likes"]
y_retweets = df_model["log_retweets"]

# %%
X_train, X_test, y_train_likes, y_test_likes, y_train_rts, y_test_rts = train_test_split(
    X,
    y_likes,
    y_retweets,
    test_size=0.2,
    random_state=42,
)

print("Train size:", X_train.shape)
print("Test size:", X_test.shape)
# Out:
# Train size: (255, 22)
# Test size: (64, 22)

# %%
rf_likes = RandomForestRegressor(n_estimators=300, random_state=42)
rf_likes.fit(X_train, y_train_likes)

pred_likes = rf_likes.predict(X_test)

mse_likes = mean_squared_error(y_test_likes, pred_likes)
rmse_likes = mse_likes ** 0.5
r2_likes = r2_score(y_test_likes, pred_likes)

print("=== Likes Prediction ===")
print("RMSE:", rmse_likes)
print("R^2:", r2_likes)
# Out:
# === Likes Prediction ===
# RMSE: 0.32263335381311686
# R^2: 0.18468884860072932

# %%
rf_rts = RandomForestRegressor(n_estimators=300, random_state=42)
rf_rts.fit(X_train, y_train_rts)

pred_rts = rf_rts.predict(X_test)

mse_rts = mean_squared_error(y_test_rts, pred_rts)
rmse_rts = mse_rts ** 0.5
r2_rts = r2_score(y_test_rts, pred_rts)

print("=== Retweets Prediction ===")
print("RMSE:", rmse_rts)
print("R^2:", r2_rts)
# Out:
# === Retweets Prediction ===
# RMSE: 0.31318054860225963
# R^2: 0.1982232042496309

# %%
importances = pd.Series(
    rf_likes.feature_importances_, 
    index=X.columns
).sort_values(ascending=False)

importances.head(20)
# Out:
# Platform_Instagram       0.130976
# Sentiment_Despair        0.127125
# Platform_Twitter         0.117071
# Sentiment_Nostalgia      0.072498
# Sentiment_Positive       0.070745
# Sentiment_Loneliness     0.061925
# Sentiment_Contentment    0.057737
# Sentiment_Joy            0.056996
# Sentiment_Excitement     0.042695
# Sentiment_Confusion      0.040156
# Sentiment_Gratitude      0.039758
# Sentiment_Sad            0.028220
# Sentiment_Grief          0.026322
# Sentiment_Pride          0.023188
# Sentiment_Happy          0.020027
# Sentiment_Curiosity      0.018459
# Sentiment_Serenity       0.018179
# Sentiment_Neutral        0.016069
# Sentiment_Embarrassed    0.014537
# Sentiment_Awe            0.012080
# dtype: float64

# %%
plot_importances = importances.head(15).reset_index()
plot_importances.columns = ["feature", "importance"]

plt.figure(figsize=(10,6))
sns.barplot(data=plot_importances, x="importance", y="feature", hue="feature", legend=False)
plt.title("Top 15 Feature Importances for Likes Prediction")
plt.xlabel("Importance")
plt.ylabel("Feature")
plt.show()

# %%
# Optional text-based regression baseline for likes.
text_reg = Pipeline([
    ("tfidf", TfidfVectorizer(max_features=5000)),
    ("reg", Ridge(alpha=1.0))
])

X_text_train, X_text_test, y_text_train, y_text_test = train_test_split(
    df_model["clean_text"],
    df_model["log_likes"],
    test_size=0.2,
    random_state=42,
)

text_reg.fit(X_text_train, y_text_train)
text_pred = text_reg.predict(X_text_test)

print("=== Text-only Ridge Regression for Likes ===")
print("RMSE:", mean_squared_error(y_text_test, text_pred) ** 0.5)
print("R^2:", r2_score(y_text_test, text_pred))
# Out:
# === Text-only Ridge Regression for Likes ===
# RMSE: 0.34563094964906266
# R^2: 0.0643140544496753

# %% [markdown]
# ### Interpretation of Engagement Prediction Results
#
# The Random Forest regression models provide exploratory baselines for engagement prediction.
#
# - **Likes Prediction:** RMSE and R² are reported above.
# - **Retweets Prediction:** RMSE and R² are reported above.
#
# Feature importance suggests that some sentiment categories, platform indicators, and hashtag count may be associated with engagement. Because engagement is also affected by missing variables such as follower count, posting time, and trending events, these results should be interpreted as predictive signals rather than causal proof.

# %% [markdown]
# # 8. Final Model Training & Interpretation
#
# In this section, we summarize the performance of the final selected models for:
#
# 1. **Sentiment Classification**
#    - Logistic Regression
#    - Linear SVM (chosen as the final model)
#
# 2. **Engagement Prediction**
#    - Random Forest Regression for Likes
#    - Random Forest Regression for Retweets
#
# We provide final performance metrics, insights into feature importance,
# and interpretations useful for business, policy, and platform strategy.

# %%
print("=== Logistic Regression (TF-IDF) ===")
print(classification_report(y_test, pred_lr, zero_division=0))

print("\n=== Linear SVM (TF-IDF) ===")
print(classification_report(y_test, pred_svm, zero_division=0))
# Out:
# === Logistic Regression (TF-IDF) ===
#               precision    recall  f1-score   support
#
#   Acceptance       1.00      1.00      1.00         2
#          Awe       1.00      0.50      0.67         2
#    Confusion       0.00      0.00      0.00         1
#  Contentment       0.00      0.00      0.00         4
#    Curiosity       1.00      0.33      0.50         3
#      Despair       0.00      0.00      0.00         2
#      Elation       0.00      0.00      0.00         1
#  Embarrassed       0.00      0.00      0.00         2
#   Excitement       0.75      0.43      0.55         7
#    Gratitude       1.00      0.33      0.50         3
#        Grief       0.00      0.00      0.00         2
#        Happy       0.00      0.00      0.00         3
#          Joy       0.23      0.78      0.36         9
#   Loneliness       0.00      0.00      0.00         2
#      Neutral       0.00      0.00      0.00         4
#    Nostalgia       1.00      0.50      0.67         2
# ...

# %%
from sklearn.metrics import accuracy_score, f1_score

final_results_classification = pd.DataFrame({
    "Model": ["Logistic Regression", "Linear SVM"],
    "Accuracy": [
        accuracy_score(y_test, pred_lr),
        accuracy_score(y_test, pred_svm)
    ],
    "Macro-F1": [
        f1_score(y_test, pred_lr, average='macro'),
        f1_score(y_test, pred_svm, average='macro')
    ]
})

final_results_classification
# Out:
#                  Model  Accuracy  Macro-F1
# 0  Logistic Regression  0.375000  0.271243
# 1           Linear SVM  0.609375  0.705359

# %%
final_results_regression = pd.DataFrame({
    "Model": ["Random Forest (Likes)", "Random Forest (Retweets)"],
    "RMSE": [rmse_likes, rmse_rts],
    "R^2": [r2_likes, r2_rts]
})

final_results_regression
# Out:
#                       Model      RMSE       R^2
# 0     Random Forest (Likes)  0.322633  0.184689
# 1  Random Forest (Retweets)  0.313181  0.198223

# %%
final_summary_classification = final_results_classification.copy()
final_summary_classification["Task"] = "Sentiment Classification"

final_summary_regression = final_results_regression.copy()
final_summary_regression["Task"] = "Engagement Prediction"

final_summary = pd.concat(
    [final_summary_classification, final_summary_regression],
    axis=0,
    ignore_index=True,
    sort=False,
)

final_summary
# Out:
#                       Model  Accuracy  Macro-F1                      Task  \
# 0       Logistic Regression  0.375000  0.271243  Sentiment Classification
# 1                Linear SVM  0.609375  0.705359  Sentiment Classification
# 2     Random Forest (Likes)       NaN       NaN     Engagement Prediction
# 3  Random Forest (Retweets)       NaN       NaN     Engagement Prediction
#
#        RMSE       R^2
# 0       NaN       NaN
# 1       NaN       NaN
# 2  0.322633  0.184689
# 3  0.313181  0.198223

# %%
importances.head(15)
# Out:
# Platform_Instagram       0.130976
# Sentiment_Despair        0.127125
# Platform_Twitter         0.117071
# Sentiment_Nostalgia      0.072498
# Sentiment_Positive       0.070745
# Sentiment_Loneliness     0.061925
# Sentiment_Contentment    0.057737
# Sentiment_Joy            0.056996
# Sentiment_Excitement     0.042695
# Sentiment_Confusion      0.040156
# Sentiment_Gratitude      0.039758
# Sentiment_Sad            0.028220
# Sentiment_Grief          0.026322
# Sentiment_Pride          0.023188
# Sentiment_Happy          0.020027
# dtype: float64

# %% [markdown]
# ### Key Predictive Features (Likes)
#
# - Several sentiment categories and platform indicators appear among the more important features in this exploratory model.
# - Platform indicators may help explain engagement differences across social media contexts.
# - `hashtag_count` also contributes to the model, which is consistent with the idea that hashtags may improve visibility and discoverability.

# %%
plot_importances = importances.head(12).reset_index()
plot_importances.columns = ["feature", "importance"]

plt.figure(figsize=(10,6))
sns.barplot(data=plot_importances, x="importance", y="feature", hue="feature", legend=False)
plt.title("Top Predictive Features for Likes")
plt.xlabel("Importance")
plt.ylabel("Feature")
plt.show()

# %% [markdown]
# ### Interpretation of Final Model Results
#
# **Sentiment Classification**
#
# The Linear SVM with TF-IDF features performed best among the baseline models tested in this notebook. This suggests that the Top 20 sentiment categories contain some distinguishable text patterns. However, because the dataset is small and some classes have few examples, the results should be interpreted as a baseline rather than a production-level NLP model.
#
# **Engagement Prediction**
#
# The Random Forest models show that sentiment, platform, and hashtag-related features contain some predictive signal for likes and retweets. However, engagement is influenced by many factors that are not included in this dataset, such as follower count, posting time, account popularity, and external events. Therefore, the regression results are best understood as exploratory modeling rather than strong engagement prediction.

# %% [markdown]
# ### Limitations
#
# - The dataset is relatively small, which limits the reliability of model evaluation and statistical testing.
# - Some sentiment classes have few samples, so macro-F1 and per-class metrics can be unstable.
# - The dataset may not be evenly sampled across countries, platforms, or time periods.
# - Sentiment labels may be noisy or ambiguous depending on annotation quality.
# - Chi-square tests may be affected by sparse contingency tables, even after restricting analysis to top categories.
# - Engagement metrics such as likes and retweets are influenced by many external factors not included in the dataset, such as follower count, posting time, account popularity, and trending events.
# - Restricting to the Top 20 sentiments improves stability but sacrifices emotional granularity.
#
# ### Future Work
#
# - Incorporate text embeddings such as BERT or RoBERTa for stronger sentiment classification.
# - Include user-level and timing features, such as follower count and posting hour, for stronger engagement prediction.
# - Apply topic modeling to connect sentiment with broader content themes.
# - Use causal inference methods to separate correlation from causal effects in engagement analysis.
